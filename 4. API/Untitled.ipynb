# %%
import pandas as pd
import distfit
import matplotlib.pyplot as plt
from distfit import distfit

# %%
downtime = pd.read_csv('downtime_lease_nov22.csv', low_memory=False)
downtime = downtime[(downtime['vacant_months'].notnull()) & (downtime['vacant_months'] > 0)]
downtime = downtime[(downtime['year_off_market'] > 2007) &
                        (downtime['year_off_market'] < 2021)]
downtime= downtime[~(downtime['estimated_rent'].isna())]

# %%
plt.hist(downtime['sqft_max'])
# Out:
# (array([4.20276e+05, 6.90000e+02, 1.29000e+02, 5.10000e+01, 1.40000e+01,
#         2.00000e+00, 4.00000e+00, 2.00000e+00, 1.00000e+00, 1.00000e+00]),
#  array([1.000000e+00, 4.969930e+04, 9.939760e+04, 1.490959e+05,
#         1.987942e+05, 2.484925e+05, 2.981908e+05, 3.478891e+05,
#         3.975874e+05, 4.472857e+05, 4.969840e+05]),
#  <BarContainer object of 10 artists>)

# %%
dist = distfit(todf=True)
dist.fit_transform(downtime.sqft_max)
dist.plot_summary()
# Out:
# [distfit] >fit..
# [distfit] >transform..
# [distfit] >[norm      ] [0.00 sec] [RSS: 0.0000000] [loc=2925.175 scale=5857.594]
# [distfit] >[expon     ] [0.00 sec] [RSS: 0.0000000] [loc=1.000 scale=2924.175]
# [distfit] >[pareto    ] [3.89 sec] [RSS: 0.0000000] [loc=-1.548 scale=2.548]
# [distfit] >[dweibull  ] [7.91 sec] [RSS: 0.0000000] [loc=1200.000 scale=1535.622]
# [distfit] >[t         ] [3.86 sec] [RSS: 0.0000000] [loc=1393.974 scale=830.039]
# [distfit] >[genextreme] [10.8 sec] [RSS: 0.0000000] [loc=4.124 scale=14.943]
# [distfit] >[gamma     ] [4.00 sec] [RSS: 0.0000000] [loc=50.000 scale=4.604]
# [distfit] >[lognorm   ] [4.27 sec] [RSS: 0.0000000] [loc=-0.920 scale=1630.935]
# [distfit] >[beta      ] [8.56 sec] [RSS: 0.0000000] [loc=1.000 scale=731360.993]
# [distfit] >[uniform   ] [0.00 sec] [RSS: 0.0000000] [loc=1.000 scale=496983.000]
# [distfit] >[loggamma  ] [6.69 sec] [RSS: 0.0000000] [loc=54702.268 scale=52611.644]
# [distfit] >Compute confidence interval [parametric]
# [distfit] >plot summary..
# (<Figure size 1080x576 with 1 Axes>,
#  <AxesSubplot:title={'center':'Best fit: norm'}, xlabel='Distribution name', ylabel='RSS (lower is better)'>)

# %%
dist = distfit(todf=True)
dist.fit_transform(downtime.estimated_rent)
dist.plot_summary()
# Out:
# [distfit] >fit..
# [distfit] >transform..
# [distfit] >[norm      ] [0.00 sec] [RSS: 0.0012805] [loc=22.131 scale=10.352]
# [distfit] >[expon     ] [0.00 sec] [RSS: 0.0042947] [loc=1.060 scale=21.071]
# [distfit] >[pareto    ] [7.40 sec] [RSS: 0.0044116] [loc=-6618.906 scale=6619.966]
# [distfit] >[dweibull  ] [4.10 sec] [RSS: 0.0003816] [loc=19.370 scale=6.555]
# [distfit] >[t         ] [2.29 sec] [RSS: 0.0003046] [loc=19.501 scale=5.411]
# [distfit] >[genextreme] [10.9 sec] [RSS: 0.0000303] [loc=17.419 scale=5.736]
# [distfit] >[gamma     ] [2.91 sec] [RSS: 0.0002659] [loc=4.059 scale=4.269]
# [distfit] >[lognorm   ] [9.51 sec] [RSS: 0.0008460] [loc=-67.248 scale=89.241]
# [distfit] >[beta      ] [7.50 sec] [RSS: 0.0003429] [loc=1.058 scale=10568155773.491]
# [distfit] >[uniform   ] [0.00 sec] [RSS: 0.0062170] [loc=1.060 scale=298.940]
# [distfit] >[loggamma  ] [5.98 sec] [RSS: 0.0014149] [loc=-2449.725 scale=354.212]
# [distfit] >Compute confidence interval [parametric]
# [distfit] >plot summary..
# (<Figure size 1080x576 with 1 Axes>,
#  <AxesSubplot:title={'center':'Best fit: genextreme'}, xlabel='Distribution name', ylabel='RSS (lower is better)'>)
